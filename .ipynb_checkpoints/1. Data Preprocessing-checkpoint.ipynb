# %% [markdown]
# # Importing Modules and DataSet

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

np.random.seed(0)

df1 = pd.read_csv("Worksheet in Project Topics for SS 2019.csv")
df1 = df1.replace({'yes':1,'no':0})
df1.head()
# Out:
#    card  reports       age  income     share  expenditure  owner  selfemp  \
# 0     1        0  37.66667  4.5200  0.033270   124.983300      1        0
# 1     1        0  33.25000  2.4200  0.005217     9.854167      0        0
# 2     1        0  33.66667  4.5000  0.004156    15.000000      1        0
# 3     1        0  30.50000  2.5400  0.065214   137.869200      0        0
# 4     1        0  32.16667  9.7867  0.067051   546.503300      1        0
#
#    dependents  months  majorcards  active
# 0           3      54           1      12
# 1           3      34           1      13
# 2           4      58           1       5
# 3           0      25           1       7
# 4           2      64           1       5

# %% [markdown]
# # Observing DataSet

# %% [raw]
# # This stage allows you to do basic sanity checks about the distribution of the data.
# # For example, we know that none of the values can be negative.

# %%
desc = df1.describe()
print(desc)
# Out:
#               card      reports          age       income        share  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.775588     0.456406    33.213103     3.365376     0.068732
# std       0.417353     1.345267    10.142783     1.693902     0.094656
# min       0.000000     0.000000     0.166667     0.210000     0.000109
# 25%       1.000000     0.000000    25.416670     2.243750     0.002316
# 50%       1.000000     0.000000    31.250000     2.900000     0.038827
# 75%       1.000000     0.000000    39.416670     4.000000     0.093617
# max       1.000000    14.000000    83.500000    13.500000     0.906320
#
#        expenditure        owner      selfemp   dependents       months  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean    185.057071     0.440485     0.068992     0.993935    55.267627
# std     272.218917     0.496634     0.253536     1.247745    66.271746
# ...

# %%
print('Total No. of accepted cards = ',df1['card'][df1['card']==1].count())
print('Total No. of rejected cards = ',df1['card'][df1['card']==0].count())
print(desc.card)
# Out:
# Total No. of accepted cards =  1023
# Total No. of rejected cards =  296
# count    1319.000000
# mean        0.775588
# std         0.417353
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: card, dtype: float64

# %%
print('Value counts:\n',df1['reports'].value_counts())
print(desc.reports)
# Out:
# Value counts:
#  0     1060
# 1      137
# 2       50
# 3       24
# 4       17
# 5       11
# 7        6
# 6        5
# 11       4
# 9        2
# 14       1
# 12       1
# 10       1
# Name: reports, dtype: int64
# count    1319.000000
# mean        0.456406
# std         1.345267
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        14.000000
# Name: reports, dtype: float64

# %%
print('Total counts = ',df1['age'].count())
print(desc.age)
# Out:
# Total counts =  1319
# count    1319.000000
# mean       33.213103
# std        10.142783
# min         0.166667
# 25%        25.416670
# 50%        31.250000
# 75%        39.416670
# max        83.500000
# Name: age, dtype: float64

# %%
print('Total counts = ',df1['income'].count())
print(desc.income)
# Out:
# Total counts =  1319
# count    1319.000000
# mean        3.365376
# std         1.693902
# min         0.210000
# 25%         2.243750
# 50%         2.900000
# 75%         4.000000
# max        13.500000
# Name: income, dtype: float64

# %%
print('Total counts = ',df1['expenditure'].count())
print(desc.expenditure)
# Out:
# Total counts =  1319
# count    1319.000000
# mean      185.057071
# std       272.218917
# min         0.000000
# 25%         4.583333
# 50%       101.298300
# 75%       249.035800
# max      3099.505000
# Name: expenditure, dtype: float64

# %%
print('Total No. of applicants who does not live in their own house = ',df1['owner'][df1['owner']==0].count())
print('Total No. of applicants who live in their own house = ',df1['owner'][df1['owner']==1].count())
print(desc.owner)
# Out:
# Total No. of applicants who does not live in their own house =  738
# Total No. of applicants who live in their own house =  581
# count    1319.000000
# mean        0.440485
# std         0.496634
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: owner, dtype: float64

# %%
print('Total No. of self employeed applicants = ',df1['selfemp'][df1['selfemp']==1].count())
print('Total No. of not self employeed applicants = ',df1['selfemp'][df1['selfemp']==0].count())
print(desc.selfemp)
# Out:
# Total No. of self employeed applicants =  91
# Total No. of not self employeed applicants =  1228
# count    1319.000000
# mean        0.068992
# std         0.253536
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: selfemp, dtype: float64

# %%
print('Total counts = ',df1['months'].count())
print(desc.months)
# Out:
# Total counts =  1319
# count    1319.000000
# mean       55.267627
# std        66.271746
# min         0.000000
# 25%        12.000000
# 50%        30.000000
# 75%        72.000000
# max       540.000000
# Name: months, dtype: float64

# %%
print('Total No. of major card holder applicants = ',df1['majorcards'][df1['majorcards']==1].count())
print('Total No. of applicants who does not have major card = ',df1['majorcards'][df1['majorcards']==0].count())
print(desc.majorcards)
# Out:
# Total No. of major card holder applicants =  1078
# Total No. of applicants who does not have major card =  241
# count    1319.000000
# mean        0.817286
# std         0.386579
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: majorcards, dtype: float64

# %%
print('Value counts:\n',df1['active'].value_counts())
print(desc.active)
# Out:
# Value counts:
#  0     219
# 2      92
# 3      91
# 5      86
# 4      84
# 7      82
# 1      73
# 6      72
# 9      71
# 11     63
# 8      62
# 10     44
# 13     42
# 12     38
# 16     30
# 14     30
# 15     27
# 17     23
# 19     21
# 18     20
# 20      9
# 22      9
# 21      7
# 23      5
# 25      4
# 27      3
# 31      2
# 28      2
# 29      2
# 33      1
# 32      1
# 44      1
# 26      1
# 24      1
# 46      1
# Name: active, dtype: int64
# count    1319.000000
# mean        6.996967
# std         6.305812
# min         0.000000
# 25%         2.000000
# 50%         6.000000
# 75%        11.000000
# max        46.000000
# Name: active, dtype: float64

# %% [raw]
# # We can see with data.shape that this is a small dataset (1312 rows),
# # so we should use cross-validation to ensure accurate measures of model quality

# %%
df1.shape
# Out:
# (1319, 12)

# %% [raw]
# # The Co-Relations of columns

# %%
df1.corr()
# Out:
#                  card   reports       age    income     share  expenditure  \
# card         1.000000 -0.452577  0.000537  0.094308  0.388028     0.365814
# reports     -0.452577  1.000000  0.044089  0.011023 -0.159011    -0.136538
# age          0.000537  0.044089  1.000000  0.324653 -0.115697     0.014948
# income       0.094308  0.011023  0.324653  1.000000 -0.054429     0.281104
# share        0.388028 -0.159011 -0.115697 -0.054429  1.000000     0.838779
# expenditure  0.365814 -0.136538  0.014948  0.281104  0.838779     1.000000
# owner        0.147826 -0.053570  0.367749  0.324776 -0.015764     0.093180
# selfemp     -0.054340  0.018835  0.100421  0.112294 -0.078905    -0.035638
# dependents  -0.036126  0.019731  0.212146  0.317601 -0.082618     0.052664
# months      -0.000268  0.048968  0.436426  0.130346 -0.055348    -0.029007
# majorcards   0.107769 -0.007304  0.009777  0.107138  0.051470     0.077514
# ...

# %% [raw]
# # Since this dataset is quite small, we'll use plot both basic histograms and relationships between columns.
# # Each plot is pretty small...
# # but it's so easy to do this way that you can include this step in even a cursory data review.

# %%
sns.pairplot(df1)
plt.savefig("PAIRPLOT1.png")

# %% [raw]
# # Boxplot of x='card' and y='dependents' to see the outlairs

# %%
sns.boxplot(x='card',y='dependents',data=df1)

# %% [raw]
# # Boxplot of x='card' and y='dependents' to see the outlairs depending on 'owner'

# %%
sns.boxplot(x='card',y='dependents',data=df1,hue='owner')

# %% [raw]
# # Boxplot of x='card' and y='expenditure' to see the outlairs

# %%
sns.boxplot(x='card',y='expenditure',data=df1)

# %% [raw]
# # Boxplot of x='card' and y='months' to see the outlairs

# %%
sns.boxplot(x='card',y='months',data=df1)

# %% [raw]
# # The dependents histogram looks odd.
# # Why would there be gaps? Let's take a closer look.
# # Since we know there are only a small number of unique values, we can just print the raw value counts.

# %% [raw]
# # A few variables look suspicious. For example,
# # does expenditure mean expenditure on this card or on cards used before appying?
# # At this point, basic data comparisons can be very helpful:

# %%
expenditures_cardholders = df1.expenditure[df1.card==1]
expenditures_noncardholders = df1.expenditure[df1.card==0]

print('Percentage of those who received a card with expenditures: %.2f'
      %(( expenditures_cardholders == 0).mean()*100))
print("Percentage of those who haven't received a card with no expenditures: %.2f"
      %((expenditures_noncardholders == 0).mean()*100))
# Out:
# Percentage of those who received a card with expenditures: 2.05
# Percentage of those who haven't received a card with no expenditures: 100.00

# %%
# Verifying the total no of rows

# %%
len(expenditures_cardholders)+len(expenditures_noncardholders)
# Out:
# 1319

# %% [markdown]
# # Features Selection and Extraction

# %% [raw]
# # majorcards appears to be a boolean rather than a count, contrary to the manual.
# # The maximum value for Active is suprisingly high, but theoretically possible.
# # A domain expert might be able to shed light on this.
# # The share column is supposed to equal the ratio of monthly credit card expenditure to yearly income.
# # Given that the minimum expenditure is zero and the minimum share is not,
# # there's either an error in the manual or with the calculation of share.
#
# # The minimum age is implausibly low, as the manual noted.
# # 50% of the population falls within a 15 year age range.
# # I would have expected a random sample of credit card holders to be more uniformly distributed across the adult age range.
# # If possible, it would be helpful to understand the original sampling process.
# # expenditure is a proxy variable

# %%
leaks = ['expenditure','dependents','months','majorcards','owner','selfemp','active','age']
df2 = df1.drop(leaks, axis=1)
df2.head()
# Out:
#    card  reports  income     share
# 0     1        0  4.5200  0.033270
# 1     1        0  2.4200  0.005217
# 2     1        0  4.5000  0.004156
# 3     1        0  2.5400  0.065214
# 4     1        0  9.7867  0.067051

# %%
sns.pairplot(df2,hue='card')
plt.savefig("PAIRPLOT2.png")

# %% [markdown]
# # Saving the pre-processed data as CSV

# %%
df2.to_csv('Pre-processed Data.csv',index=False)
